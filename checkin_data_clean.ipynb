# %% [markdown]
# <a href="https://colab.research.google.com/github/pony-yyy/GroupWork/blob/main/checkin_data_clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Authenticate and access Google Cloud services
from google.colab import auth
auth.authenticate_user()

# %%
# Import the necessary libraries
from google.cloud import storage
from google.cloud import bigquery

project_id = "bdao-ima-422711"
dataset_name = "bobbdaoima"
table_name = "restaurant_checkin" # if you make changes previously, then here you need to make according change

bigquery_client = bigquery.Client(project=project_id)

# %%
# Query all data from the table
query = f"""
   SELECT DISTINCT business_id, total_number_of_checkin
   FROM `{project_id}.{dataset_name}.{table_name}`
   ORDER BY business_id;

"""

query_job = bigquery_client.query(query)
results = query_job.result()

checkin_df = query_job.to_dataframe()
checkin_df
# Out:
#                   business_id  total_number_of_checkin
# 0      ---kPU91CF4Lq2-WlRu9Lw                       11
# 1      --0iUa4sNDFiZFrAdIWhZQ                       10
# 2      --7PUidqRWpRSpXebiyxTg                       10
# 3      --8IbOsAAxjKRoYsBFL-PA                       32
# 4      --ZVrH2X2QXBFdCilbirsw                       67
# ...                       ...                      ...
# 51313  zzjFdJwXuxBOGe9JeY_EMw                       27
# 51314  zznJox6-nmXlGYNWgTDwQQ                       67
# 51315  zznZqH9CiAznbkV6fXyHWA                        1
# 51316  zzu6_r3DxBJuXcjnOYVdTw                       23
# 51317  zzyx5x0Z7xXWWvWnZFuxlQ                        1
#
# [51318 rows x 2 columns]

# %%
from google.cloud import bigquery

project_id = "bdao-ima-422711"

dataset_name = "bobbdaoima"
table_name = "checkin_data"

bigquery_client = bigquery.Client(project=project_id)

job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_TRUNCATE",
)

job = bigquery_client.load_table_from_dataframe(
    checkin_df,
    f"{project_id}.{dataset_name}.{table_name}",
    job_config=job_config,
)

job.result()

print(f"Data uploaded to BigQuery table {dataset_name}.{table_name}")
# Out:
# Data uploaded to BigQuery table bobbdaoima.checkin_data
